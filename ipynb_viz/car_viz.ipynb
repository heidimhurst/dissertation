# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# for font formatting consistent with dissertation style
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Palatino'],'size':22})
rc('text', usetex=True)

# %%
def cm2inch(*tupl):
    inch = 2.54
    if isinstance(tupl[0], tuple):
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)

# %%
img_path = '../data/104_upsample/104_upsample_{}.tif'
ds_path = '../data/104_upsample/104_downsample_{}.tif'

save_path="/Users/heidihurst/Documents/UK/ucl-gis/dissertation/screenshots_images/"
# latex project figure path
# save_path= "/Users/heidihurst/Documents/UK/ucl-gis/dissertation/writeup/16819348ghkbpztpjpfj/Figures/"

# %%
ds_im = np.array(Image.open(img_path.format("1")))

# %%
plt.figure()
plt.imshow(ds_im)
plt.show()

# %%
im = np.array(Image.open(img_path.format("1")))

# %%
cars = [[[240,256],[2200,2180]],[[2585,2600],[1870,1857]],[[1863,1876],[1668,1653]]]

# %%
cars[0][0]
# Out:
# [240, 256]

# %%
len(cars)
# Out:
# 3

# %%
f = [1, 1.5, 2, 2.5, 3, 3.5, 4]
rows = ["(a)", "(b)", "(c)"]

# %%
plt.figure(figsize=(len(f), 2*len(cars)))
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
for i in range(len(cars)):
    for j in range(len(f)):
        ax = plt.subplot(len(cars),len(f),1+len(f)*i+j)
#         print(len(cars),len(f),1+len(f)*i+j)
        # plt.imshow(im[2180:2200,240:260,:])
        im = np.array(Image.open(img_path.format(f[j])))
        ax.imshow(im)
        
        # add title to first row
        if i == 0:
            ax.set_title("df {:.1f}".format(f[j]))
        
        ax.set_xlim(cars[i][0])
        ax.set_ylim(cars[i][1])
#         ax.axis("off")

#         plt.yticks(rotation=90)
    
        plt.tick_params(
#             axis='y',          # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False,         # ticks along the top edge are off
            left=False,
            labelleft=False,
            labelbottom=False)
    
#         plt.tick_params(
#             axis='x',
#             which='both',      # both major and minor ticks are affected
#             bottom=False,      # ticks along the bottom edge are off
#             top=False,         # ticks along the top edge are off
#             labelbottom=False)
        
        # add fake y label to first column
        if j == 0:
            ax.set_ylabel(rows[i], rotation=0, labelpad=20)

# plt.xlabel("test x axis")
plt.savefig(save_path + "car_example", dpi=300)
plt.show()

# %%
im = np.array(Image.open(img_path.format("1")))
plt.imshow(im)
plt.xlim([1863,1876])
plt.ylim([1668,1653])
plt.show()
# Out:
# /Users/heidihurst/anaconda/envs/images27/lib/python2.7/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# cols = ["df {:.1f}".format(fact) for fact in f]


# fig, axes = plt.subplots(nrows=len(cars), ncols=len(f), figsize=(4*len(f)*5, 4*len(cars)*8))
# # plt.figure(figsize=(4*len(f)*5, 4*len(car)*8))
# # from matplotlib import rcParams
# # rcParams.update({'figure.autolayout': True})

# pad = 5
# for ax, col in zip(axes[0], cols):
#     ax.annotate(col, xy=(0.5, 1), xytext=(0, pad),
#                 xycoords='axes fraction', textcoords='offset points',
#                 size='large', ha='center', va='baseline')

# for ax, row in zip(axes[:,0], rows):
#     ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0),
#                 xycoords=ax.yaxis.label, textcoords='offset points',
#                 size='large', ha='right', va='center')


    
# # for i in range(len(cars)):
# #     for j in range(len(f)):
# #         plt.subplot(len(cars),len(f),1+len(f)*i+j)
# # #         print(len(cars),len(f),1+len(f)*i+j)
# #         # plt.imshow(im[2180:2200,240:260,:])
# #         im = np.array(Image.open(img_path.format(f[j])))
# #         plt.imshow(im)
# #         plt.xlim(cars[i][0])
# #         plt.ylim(cars[i][1])
# #         plt.axis("off")


# fig.tight_layout()
# fig.subplots_adjust(left=0.4, top=0.95)

# plt.show()

# %%
plt.figure(figsize=(len(f), len(cars)))
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True, 'font.size':14})
for i in range(len(cars)):
    for j in range(len(f)):
        plt.subplot(len(cars),len(f),1+len(f)*i+j)
#         print(len(cars),len(f),1+len(f)*i+j)
        # plt.imshow(im[2180:2200,240:260,:])
        im = np.array(Image.open(img_path.format(f[j])))
        plt.imshow(im)
        
        # add title to first row
        if i == 0:
            plt.title("df {:.1f}".format(f[j]))
            
        # add fake y label to first column
        if j == 0:
            plt.ylabel("test {}".format(i))
        
        plt.xlim(cars[i][0])
        plt.ylim(cars[i][1])
        plt.axis("off")

# plt.xlabel("test x axis")
plt.show()

# %%
plt.clf()
# plt.figure(figsize=(len(f), 2))
plt.figure(figsize=cm2inch((28,10)))
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# import matplotlib.gridspec as gridspec

# gs = gridspec.GridSpec(3,7, wspace=0.50, hspace=0.0)

# plt.subplots_adjust(wspace=0, hspace=0)

# first one - downsampled
for j in range(len(f)):
    ax = plt.subplot(2,len(f),1+len(f)*0+j)
#     ax = plt.subplot(gs[0,j])
    im = np.array(Image.open(ds_path.format(f[j])))
    ax.imshow(im)
#     ax.set_aspect(4.0/5.0)

    # add title to first row
#     if i == 0:
    ax.set_title("df {:.1f}".format(f[j]))

    ax.set_xlim([float(x)/(f[j]) for x in cars[0][0]])
    ax.set_ylim([float(x)/(f[j]) for x in cars[0][1]])

    plt.tick_params(
#             axis='y',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        left=False,
        labelleft=False,
        labelbottom=False)

    # add fake y label to first column
    if j == 0:
        ax.set_ylabel(rows[0], rotation=0, labelpad=20)

# second row - upsampled
for j in range(len(f)):
    ax = plt.subplot(2,len(f),1+len(f)*1+j)

#     ax = plt.subplot(gs[1,j])
    
    im = np.array(Image.open(img_path.format(f[j])))
    ax.imshow(im)

    ax.set_xlim(cars[0][0])
    ax.set_ylim(cars[0][1])

    plt.tick_params(
#             axis='y',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        left=False,
        labelleft=False,
        labelbottom=False)

    # add fake y label to first column
    if j == 0:
        ax.set_ylabel(rows[1], rotation=0, labelpad=20)


# plt.subplots_adjust(wspace=0, hspace=0)
# plt.xlabel("test x axis")
plt.savefig(save_path + "poster_ds_us_car_example", dpi=300)
plt.show()

# %%
plt.clf()
# plt.figure(figsize=(len(f), 2))
plt.figure(figsize=cm2inch((25,14)))
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# first one - downsampled
for i in range(3):
    for j in range(len(f)):
        ax = plt.subplot(3,len(f),1+len(f)*i+j)
        im = np.array(Image.open(img_path.format(f[j])))
        ax.imshow(im)

        if i == 0:
            ax.set_title("df {:.1f}".format(f[j]))

        ax.set_xlim(cars[i][0])
        ax.set_ylim(cars[i][1])

        plt.tick_params(
    #             axis='y',          # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False,         # ticks along the top edge are off
            left=False,
            labelleft=False,
            labelbottom=False)

        # add fake y label to first column
        if j == 0:
            ax.set_ylabel(rows[i], rotation=0, labelpad=20)

plt.savefig(save_path + "multi_car", dpi=300)
plt.show()
